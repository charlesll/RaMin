# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

import rampy
import scipy

import pickle

# %%
X = np.load('./data/excellent_unoriented/obs.npy')
y = pickle.load( open( "./data/excellent_unoriented/labels.pkl", "rb" ) )

# %%
plt.plot(X[10,:])

# %% [markdown]
# ### plt.imshow(X[:,:])

# %%
X = np.load('./data/To_Recognize/obs.npy')
y = pickle.load( open( "./data/To_Recognize/labels.pkl", "rb" ) )

# %%
plt.plot(X[0,:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-30f7ec7e9016> in <module>
# ----> 1 plt.plot(X[0,:])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
X.shape
# Out:
# (0, 1000)
